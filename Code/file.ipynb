# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Nhom_7/Dataset'
# %ls
# Out:
# /content/drive/MyDrive/Nhom_7/Dataset
# BankChurners.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('BankChurners.csv')
df
# Out:
#        CLIENTNUM  ... Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0      768805383  ...                                           0.999910
# 1      818770008  ...                                           0.999940
# 2      713982108  ...                                           0.999980
# 3      769911858  ...                                           0.999870
# 4      709106358  ...                                           0.999980
# ...          ...  ...                                                ...
# 10122  772366833  ...                                           0.999810
# 10123  710638233  ...                                           0.004729
# 10124  716506083  ...                                           0.002118
# 10125  717406983  ...                                           0.003294
# 10126  714337233  ...                                           0.003377
#
# ...

# %%
df.sample(5)
# Out:
#       CLIENTNUM  ... Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 8187  715958583  ...                                           0.999890
# 211   710565408  ...                                           0.999840
# 7664  712562433  ...                                           0.002997
# 5669  772082208  ...                                           0.999890
# 5041  719105433  ...                                           0.999690
#
# [5 rows x 23 columns]

# %%
labels=['Existing','Atrrited']
colors = ["yellow","red"]
plt.figure(figsize = (13, 6))
plt.pie(df['Attrition_Flag'].value_counts(),labels=labels,colors=colors,
        autopct='%1.2f%%', shadow=True, startangle=140) 
plt.show()

# %% [markdown]
# Chúng ta có thể thấy số lượng khách hàng còn hoạt động gấp 5 lần số lượng khách hàng bị khóa.

# %%
plt.figure(figsize = (15, 8))
sns.countplot(x = df['Card_Category'], hue = df['Gender'], edgecolor = 'black')
plt.show()

# %% [markdown]
# Thống kê số người nam nữ sài thẻ xanh, vàng, bạc, bạch *kim*

# %%
plt.figure(figsize = (15,8))
sns.countplot(x= df['Education_Level'], edgecolor = 'black', saturation = 0.55)
plt.show()

# %% [markdown]
# Thống kê trình độ học vấn của khách hàng

# %%
plt.figure(figsize = (15, 8))
sns.histplot(df['Customer_Age'],kde=True)

# %%
plt.figure(figsize = (15, 8)) 
sns.scatterplot(data=df,x='Total_Trans_Amt',y='Avg_Open_To_Buy' ,hue='Gender')

# %% [markdown]
# Biểu đồ phân tán tổng số tiền giao dich (12 tháng) và hạn mức để mua (trong 12 tháng)

# %%
fig,ax = plt.subplots(figsize = (18, 9))
a=df.groupby(['Customer_Age','Income_Category']).count()['Gender'].unstack().plot(ax=ax)
a

# %%
fig,ax = plt.subplots(figsize = (12, 6))
a=df.groupby(['Income_Category','Customer_Age']).count()['Gender'].unstack()
sns.heatmap(a,cmap="YlGnBu")

# %% [markdown]
# Thống kê mức thu nhập theo độ tuổi. Độ tuổi tầm 50 chiếm mức lương $120 cao nhất.

# %%
fig,ax = plt.subplots(figsize = (12, 6))
sns.countplot(x='Attrition_Flag', data=df, hue='Gender')
plt.title("Distribution of Gender Among Attrited and Existing Customers")
plt.show()

# %%
fig,ax = plt.subplots(figsize = (12, 6))
sns.countplot(x='Attrition_Flag', data=df, hue='Marital_Status')
plt.title("Distribution of Marital Status Among Attrited and Existing Customers")
plt.show()

# %%
fig,ax = plt.subplots(figsize = (12, 6))
sns.countplot(x='Attrition_Flag', data=df, hue='Card_Category')
plt.title("Distribution of Card_Category Among Attrited and Existing Customers")
plt.show()

# %%
fig,ax = plt.subplots(figsize = (12, 6))
sns.countplot(x='Attrition_Flag', data=df, hue='Income_Category')
plt.title("Distribution of Income Category Among Attrited and Existing Customers")
plt.show()
